# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Iris.csv")

# %%
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
dataset.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataset.head().head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataset.tail().tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataset.shape
# Out:
# (150, 6)

# %%
df=pd.DataFrame(dataset)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
a=df.isnull()
a
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# Id               0.0
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Remove S.No. column from data
df = df.drop(['Id'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['Brand'] = df.Species.str.split().str.get(0)

# %%
df['Model'] = df.Species.str.split().str.get(1) + df.Species.str.split().str.get(2)

# %%
df[['Species','Brand','Model']]
# Out:
#             Species           Brand  Model
# 0       Iris-setosa     Iris-setosa    NaN
# 1       Iris-setosa     Iris-setosa    NaN
# 2       Iris-setosa     Iris-setosa    NaN
# 3       Iris-setosa     Iris-setosa    NaN
# 4       Iris-setosa     Iris-setosa    NaN
# ..              ...             ...    ...
# 145  Iris-virginica  Iris-virginica    NaN
# 146  Iris-virginica  Iris-virginica    NaN
# 147  Iris-virginica  Iris-virginica    NaN
# 148  Iris-virginica  Iris-virginica    NaN
# 149  Iris-virginica  Iris-virginica    NaN
#
# [150 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Age            150 non-null    int64
#  6   Brand          150 non-null    object
#  7   Model          0 non-null      float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 9.5+ KB

# %%
df=df.drop(['Model'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Age            150 non-null    int64
#  6   Brand          150 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.3+ KB

# %%
print(df.Brand.unique())
print(df.Brand.nunique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# 3

# %%
searchfor = ['Iris-setosa', 'Iris-versicolor' ,'Iris-virginica']
df[df.Brand.str.contains('|'.join(searchfor))].head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
#
#     Age        Brand
# 0  2025  Iris-setosa
# 1  2025  Iris-setosa
# 2  2025  Iris-setosa
# 3  2025  Iris-setosa
# 4  2025  Iris-setosa

# %%
df["Brand"].replace({"Iris-setosa": "Isuzu", "Iris-versicolor": "Mini Cooper","Iris-virginica":"Land Rover"}, inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_2316\2955735261.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Brand"].replace({"Iris-setosa": "Isuzu", "Iris-versicolor": "Mini Cooper","Iris-virginica":"Land Rover"}, inplace=True)

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%      50%     75%  \
# SepalLengthCm  150.0     5.843333  0.828066     4.3     5.1     5.80     6.4
# SepalWidthCm   150.0     3.054000  0.433594     2.0     2.8     3.00     3.3
# PetalLengthCm  150.0     3.758667  1.764420     1.0     1.6     4.35     5.1
# PetalWidthCm   150.0     1.198667  0.763161     0.1     0.3     1.30     1.8
# Age            150.0  2025.000000  0.000000  2025.0  2025.0  2025.00  2025.0
#
#                   max
# SepalLengthCm     7.9
# SepalWidthCm      4.4
# PetalLengthCm     6.9
# PetalWidthCm      2.5
# Age            2025.0

# %%
df.describe(include='all').T
# Out:
#                count unique          top freq      mean       std     min  \
# SepalLengthCm  150.0    NaN          NaN  NaN  5.843333  0.828066     4.3
# SepalWidthCm   150.0    NaN          NaN  NaN     3.054  0.433594     2.0
# PetalLengthCm  150.0    NaN          NaN  NaN  3.758667   1.76442     1.0
# PetalWidthCm   150.0    NaN          NaN  NaN  1.198667  0.763161     0.1
# Species          150      3  Iris-setosa   50       NaN       NaN     NaN
# Age            150.0    NaN          NaN  NaN    2025.0       0.0  2025.0
# Brand            150      3        Isuzu   50       NaN       NaN     NaN
#
#                   25%     50%     75%     max
# SepalLengthCm     5.1     5.8     6.4     7.9
# SepalWidthCm      2.8     3.0     3.3     4.4
# PetalLengthCm     1.6    4.35     5.1     6.9
# PetalWidthCm      0.3     1.3     1.8     2.5
# Species           NaN     NaN     NaN     NaN
# Age            2025.0  2025.0  2025.0  2025.0
# Brand             NaN     NaN     NaN     NaN

# %%
cat_cols=df.select_dtypes(include=['object']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)     
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Species', 'Brand'], dtype='object')
# Numerical Variables:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Age']

# %%
import seaborn as sns
for col in num_cols:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# SepalLengthCm
# Skew : 0.31
# SepalWidthCm
# Skew : 0.33
# PetalLengthCm
# Skew : -0.27
# PetalWidthCm
# Skew : -0.1
# Age
# Skew : 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Automatically determine number of rows and columns for subplot grid
n_cols = 2
n_rows = (len(cat_cols) + 1) // n_cols

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows * 6))
fig.suptitle('Bar Plot for All Categorical Variables in the Dataset', fontsize=20)
axes = axes.flatten()

# Plot each categorical column dynamically
for i, col in enumerate(cat_cols):
    order = df[col].value_counts().index[:20]  # Limit to top 20 categories for visibility
    sns.countplot(ax=axes[i], x=col, data=df, color='blue', order=order)
    axes[i].set_title(f'{col} Distribution')
    axes[i].tick_params(axis='x', rotation=45 if df[col].nunique() > 5 else 0)

# Hide any extra unused axes
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout to accommodate title and spacing
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
import numpy as np

def log_transform(data, cols):
    for colname in cols:
        # Avoid negative or zero values for log
        if (data[colname] <= 0).any():
            # Shift values if necessary (e.g. min = 0 -> add 1)
            min_val = data[colname].min()
            shift = 1 - min_val if min_val <= 0 else 0
            data[colname + '_log'] = np.log(data[colname] + shift)
            print(f"[Shifted] Log transformed '{colname}' with shift = {shift}")
        else:
            data[colname + '_log'] = np.log(data[colname])
            print(f"[Log] Transformed '{colname}'")

    print("\n✅ Transformation Complete.\n")
    data.info()

# %%
# Optional: Auto-log transform skewed numeric features
from scipy.stats import skew

skewed = [col for col in num_cols if abs(df[col].skew()) > 1 and df[col].min() > 0]
log_transform(df, skewed)
# Out:
# ✅ Transformation Complete.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Age            150 non-null    int64
#  6   Brand          150 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.3+ KB
